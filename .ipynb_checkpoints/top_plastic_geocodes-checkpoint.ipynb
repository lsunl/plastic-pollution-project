# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import gkey

# %%
# Import countries file as DataFrame
mismanagement_pd = pd.read_csv("mismanagement_countries.csv")
mismanagement_pd.head()
# Out:
#        country economic_status1 coastal_population2  \
# 0        China              UMI         262,892,387
# 1    Indonesia              LMI         187,223,476
# 2  Philippines              LMI          83,446,862
# 3     Vietnam8              LMI          55,858,245
# 4    Sri Lanka              LMI          14,568,174
#
#    waste_generation_rate_kg_per_person3  percentage_plastic_in_waste_stream4  \
# 0                                  1.10                                   11
# 1                                  0.52                                   11
# 2                                  0.50                                   15
# 3                                  0.79                                   13
# 4                                  5.10                                    7
#
#    percentage_inadequately_managed_waste5  percentage_littered_waste6  \
# 0                                      74                           2
# 1                                      81                           2
# 2                                      81                           2
# 3                                      86                           2
# 4                                      82                           2
#
#   waste_generation_kg_day7 plastic_waste_generation_kg_day7  \
# 0              289,181,626                       31,665,388
# 1               97,356,208                       10,660,505
# 2               41,723,431                        6,237,653
# 3               44,128,014                        5,714,578
# 4               74,297,687                        5,163,689
#
#   inadequately_managed_plastic_waste_kg_day7 plastic_waste_littered_kg_day7  \
# 0                                 23,530,300                        633,308
# 1                                  8,600,093                        213,210
# 2                                  5,035,956                        124,753
# 3                                  4,909,870                        114,292
# 4                                  4,256,120                        103,274
#
#    mismanaged_plastic waste_kg_person_day7  \
# 0                                    0.092
# 1                                    0.047
# 2                                    0.062
# 3                                    0.090
# 4                                    0.299
#
#   mismanaged_plastic_waste_2010_tonnes7 mismanaged_plastic_waste_2025_tonnes7  \
# 0                             8,819,717                           17,814,777
# 1                             3,216,856                            7,415,202
# 2                             1,883,659                            5,088,394
# 3                             1,833,819                            4,172,828
# 4                             1,591,179                            1,918,670
#
#
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
country_codes = mismanagement_pd

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in mismanagement_pd.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    country = row['country']

    # update address key value
    params['address'] = f"{city},{state}"

    # make request
    cities_lat_lng = requests.get(base_url, params=params)
    
    # print the cities_lat_lng url, avoid doing for public github repos in order to avoid exposing key
    print(cities_lat_lng.url)
    
    # convert to json
#     mismanagement_lat_lng = mismanagement_lat_lng.json()

#     mismanagement_pd.loc[index, "Lat"] = mismanagement_lat_lng["results"][0]["geometry"]["location"]["lat"]
#     mismanagement_pd.loc[index, "Lng"] = mismanagement_lat_lng["results"][0]["geometry"]["location"]["lng"]

# # Visualize to confirm lat lng appear
    mismanagement_pd.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a97f6d4d9f27> in <module>
#      10
#      11     # update address key value
# ---> 12     params['address'] = f"{city},{state}"
#      13
#      14     # make request
#
# NameError: name 'city' is not defined

# %%
# Target countries
target_city = "Boise, Idaho"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city, gkey)
target_url
