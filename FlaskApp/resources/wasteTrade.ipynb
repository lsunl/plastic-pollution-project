# %%
import pandas as pd
import numpy

# %%
file = "assets/data/plasticwastetrade-bycountry-1988-2018.csv"

# %%
df = pd.read_csv(file)
df2 = df.groupby('Reporter')
df
# Out:
#      Classification  Year  Period  Period Desc.  Aggregate Level  \
# 0                H5  2018    2018          2018                4
# 1                H5  2018    2018          2018                4
# 2                H5  2018    2018          2018                6
# 3                H5  2018    2018          2018                6
# 4                H5  2018    2018          2018                6
# 5                H5  2018    2018          2018                4
# 6                H5  2018    2018          2018                4
# 7                H5  2018    2018          2018                6
# 8                H5  2018    2018          2018                6
# 9                H5  2018    2018          2018                6
# 10               H5  2018    2018          2018                6
# 11               H5  2018    2018          2018                4
# 12               H5  2018    2018          2018                6
# ...

# %%
df2 = df.iloc[:,[1,6,7,8,9,29,31]]

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
connection_string = "root:root@localhost/plasticdb"
engine = create_engine(f'mysql://{connection_string}')

# %%
df2.to_sql(name='trades', con= engine, if_exists='append', index=False)
